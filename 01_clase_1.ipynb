# %% [markdown]
# # CLASE PROGRAMACIÓN
#
# ## CLASE 1
#
# ### Diego Zuluaga
#
# Esta es la primera clase.
#
# - Variable
# - Tipos de dato
# - Print

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
primer_nombre = "Mauricio"
edad = 20
activo = False

# %%
print(primer_nombre)
print(edad)
print("\n")
print("Mi nombre es", primer_nombre, "y tengo", edad, "años.")
# Out:
# Mauricio
# 20
#
#
# Mi nombre es Mauricio y tengo 20 años.

# %%
type(primer_nombre)
# Out:
# str

# %%
type(activo)
# Out:
# bool

# %%
print("´Hola´ ")
# Out:
# ´Hola´

# %%
saludo = "Hola " + primer_nombre
print(saludo)
# Out:
# Hola Mauricio
