# %% [markdown]
# # CLASE 2
#
# ## Fecha: 11/02/2026
#
# ### Diego Zuluaga

# %%
nombre = "Diego"

# %%
print(nombre.upper())
# Out:
# DIEGO

# %%
print("Cargo".upper())
# Out:
# CARGO

# %%
variable = 10

# %%
print("El resultado es: ", variable)
# Out:
# El resultado es:  10

# %%
apellido = input("Ingrese su apellido: ")

# %%
nombre_completo = input("Ingrese su nombre completo: ")

# %%
print("El cliente", apellido, "compró un producto")
# Out:
# El cliente Zuluaga compró un producto

# %%
edad = input("Ingrese su edad: ") # El input siempre devuelve un string

# %%
edad = int(input("Ingrese su edad: ")) # Convertir el string a un entero para poder realizar operaciones matemáticas con él.

# %%
apellido_1 = (input("Ingrese su apellido: ").upper())

# %%
apellido_2 = (input("Ingrese su apellido: ").lower())

# %%
apellido_3 = (input("Ingrese su apellido: ").strip())

# %%
apellido_4 = (input("Ingrese su apellido: ").upper().strip())

# %% [markdown]
# ## EJERCICIO VALOR FUTURO CON PYTHON

# %%
# Solicitud de datos al usuario transformados a int

principal_vp = int(input("Introduce el monto inicial invertido (vP): "))
tasa_interes_i = int(input("Introduce la tasa de interés anual (%) (i): "))
años_n = int(input("Introduce el número de años (n): "))
 
# Cálculo del Valor Futuro (Interés Simple)
# Dividimos la tasa entre 100 para convertir el número entero a decimal
valor_futuro = principal_vp * (1 + (tasa_interes_i / 100)) ** años_n
 
print("-" * 30)

print(f"Al final de {años_n} años, tu inversión de ${principal_vp} valdrá: ${valor_futuro:.2f}")
# Out:
# ------------------------------
# Al final de 5 años, tu inversión de $10 valdrá: $16.11

# %%
# Solicitud de datos al usuario 
# transformados 
# a int

apellido_4 = (input("Ingrese su apellido: ").upper().strip())

"""
Este es un comentario de varias líneas. 
Se puede usar para explicar partes del código o para escribir notas. 
No afecta la ejecución del programa.

"""
